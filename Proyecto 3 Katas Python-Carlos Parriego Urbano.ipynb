# %% [markdown]
# # Proyecto 3 - Katas Python - Carlos Parriego Urbano

# %% [markdown]
# Notebook realizado para resolver los ejercicios del Proyecto 3 de Python. Cada ejercicio incluye el enunciado y su respuesta en Python.

# %% [markdown]
# ## Ejercicio 1
#
# **Enunciado:** Escribe una función que reciba una cadena de texto como parámetro y devuelva un diccionario con las frecuencias de cada letra en la cadena. Los espacios no deben ser considerados.

# %%
def contar_frecuencias(cadena):
    frecuencias = {}

    for letra in cadena:
        if letra != " ":
            frecuencias[letra] = frecuencias.get(letra, 0) + 1

    return frecuencias

print(contar_frecuencias("hola mundo"))
# Out:
# {'h': 1, 'o': 2, 'l': 1, 'a': 1, 'm': 1, 'u': 1, 'n': 1, 'd': 1}

# %% [markdown]
# ## Ejercicio 2
#
# **Enunciado:** Dada una lista de números, obtén una nueva lista con el doble de cada valor. Usa la función map().

# %%
numeros = [1, 2, 3, 4, 5]

dobles = list(map(lambda numero: numero * 2, numeros))

print(dobles)
# Out:
# [2, 4, 6, 8, 10]

# %% [markdown]
# ## Ejercicio 3
#
# **Enunciado:** Escribe una función que tome una lista de palabras y una palabra objetivo como parámetros. La función debe devolver una lista con todas las palabras de la lista original que contengan la palabra objetivo.

# %%
def buscar_palabra_objetivo(lista_palabras, palabra_objetivo):
    resultado = list(filter(lambda palabra: palabra_objetivo in palabra, lista_palabras))
    return resultado

palabras = ["casa", "caseta", "perro", "cascada", "gato"]
print(buscar_palabra_objetivo(palabras, "cas"))
# Out:
# ['casa', 'caseta', 'cascada']

# %% [markdown]
# ## Ejercicio 4
#
# **Enunciado:** Genera una función que calcule la diferencia entre los valores de dos listas. Usa la función map().

# %%
def calcular_diferencias(lista1, lista2):
    diferencias = list(map(lambda x, y: x - y, lista1, lista2))
    return diferencias

numeros1 = [10, 20, 30]
numeros2 = [1, 5, 12]

print(calcular_diferencias(numeros1, numeros2))
# Out:
# [9, 15, 18]

# %% [markdown]
# ## Ejercicio 5
#
# **Enunciado:** Escribe una función que tome una lista de números como parámetro y un valor opcional nota_aprobado (por defecto 5). La función debe calcular la media de los números en la lista y determinar si la media es mayor o igual que nota_aprobado. Si es así, el estado será "aprobado"; de lo contrario, "suspenso". La función debe devolver una tupla que contenga la media y el estado.

# %%
def evaluar_media(notas, nota_aprobado=5):
    media = sum(notas) / len(notas)

    if media >= nota_aprobado:
        estado = "aprobado"
    else:
        estado = "suspenso"

    return (media, estado)

print(evaluar_media([6, 7, 5, 8]))
# Out:
# (6.5, 'aprobado')

# %% [markdown]
# ## Ejercicio 6
#
# **Enunciado:** Escribe una función que calcule el factorial de un número de manera recursiva.

# %%
def factorial(numero):
    if numero == 0 or numero == 1:
        return 1
    else:
        return numero * factorial(numero - 1)

print(factorial(5))
# Out:
# 120

# %% [markdown]
# ## Ejercicio 7
#
# **Enunciado:** Genera una función que convierta una lista de tuplas a una lista de strings. Usa la función map().

# %%
def convertir_tuplas_a_strings(lista_tuplas):
    resultado = list(map(str, lista_tuplas))
    return resultado

tuplas = [(1, 2), (3, 4), (5, 6)]
print(convertir_tuplas_a_strings(tuplas))
# Out:
# ['(1, 2)', '(3, 4)', '(5, 6)']

# %% [markdown]
# ## Ejercicio 8
#
# **Enunciado:** Escribe un programa que pida al usuario dos números e intente dividirlos. Si el usuario ingresa un valor no numérico o intenta dividir por cero, maneja esas excepciones de manera adecuada y muestra un mensaje indicando si la división fue exitosa o no.

# %%
def dividir_seguro(numero1, numero2):
    try:
        resultado = numero1 / numero2
        return f"La división fue exitosa. Resultado: {resultado}"
    except ZeroDivisionError:
        return "Error: no se puede dividir entre cero."
    except TypeError:
        return "Error: debes introducir valores numéricos."


print(dividir_seguro(10, 2))
print(dividir_seguro(10, 0))
# Out:
# La división fue exitosa. Resultado: 5.0
# Error: no se puede dividir entre cero.

# %% [markdown]
# ## Ejercicio 9
#
# **Enunciado:** Escribe una función que tome una lista de nombres de mascotas como parámetro y devuelva una nueva lista excluyendo ciertas mascotas prohibidas en España. La lista de mascotas a excluir es ["Mapache", "Tigre", "Serpiente Pitón", "Cocodrilo", "Oso"]. Usa la función filter().

# %%
def filtrar_mascotas(mascotas):
    mascotas_prohibidas = ["Mapache", "Tigre", "Serpiente Pitón", "Cocodrilo", "Oso"]
    permitidas = list(filter(lambda mascota: mascota not in mascotas_prohibidas, mascotas))
    return permitidas

lista_mascotas = ["Perro", "Mapache", "Gato", "Tigre", "Conejo"]
print(filtrar_mascotas(lista_mascotas))
# Out:
# ['Perro', 'Gato', 'Conejo']

# %% [markdown]
# ## Ejercicio 10
#
# **Enunciado:** Escribe una función que reciba una lista de números y calcule su promedio. Si la lista está vacía, lanza una excepción personalizada y maneja el error adecuadamente.

# %%
class ListaVaciaError(Exception):
    pass


def calcular_promedio(numeros):
    if len(numeros) == 0:
        raise ListaVaciaError("La lista está vacía. No se puede calcular el promedio.")

    return sum(numeros) / len(numeros)

try:
    print(calcular_promedio([4, 6, 8, 10]))
except ListaVaciaError as error:
    print(f"Error: {error}")
# Out:
# 7.0

# %% [markdown]
# ## Ejercicio 11
#
# **Enunciado:** Escribe un programa que pida al usuario que introduzca su edad. Si el usuario ingresa un valor no numérico o un valor fuera del rango esperado (por ejemplo, menor que 0 o mayor que 120), maneja las excepciones adecuadamente.

# %%
def comprobar_edad(edad):
    try:
        if edad < 0 or edad > 120:
            raise ValueError("La edad debe estar entre 0 y 120 años.")
        return f"Edad registrada correctamente: {edad}"
    except ValueError as error:
        return f"Error: {error}"


print(comprobar_edad(18))
print(comprobar_edad(130))
# Out:
# Edad registrada correctamente: 18
# Error: La edad debe estar entre 0 y 120 años.

# %% [markdown]
# ## Ejercicio 12
#
# **Enunciado:** Genera una función que, al recibir una frase, devuelva una lista con la longitud de cada palabra. Usa la función map().

# %%
def longitud_palabras(frase):
    palabras = frase.split()
    longitudes = list(map(len, palabras))
    return longitudes

print(longitud_palabras("Python es muy útil"))
# Out:
# [6, 2, 3, 4]

# %% [markdown]
# ## Ejercicio 13
#
# **Enunciado:** Genera una función que, para un conjunto de caracteres, devuelva una lista de tuplas con cada letra en mayúsculas y minúsculas. Las letras no pueden estar repetidas. Usa la función map().

# %%
def mayusculas_minusculas(caracteres):
    letras_unicas = set(filter(lambda caracter: caracter.isalpha(), caracteres))
    resultado = list(map(lambda letra: (letra.upper(), letra.lower()), letras_unicas))
    return resultado

print(mayusculas_minusculas("Hola Mundo"))
# Out:
# [('L', 'l'), ('A', 'a'), ('D', 'd'), ('H', 'h'), ('N', 'n'), ('M', 'm'), ('U', 'u'), ('O', 'o')]

# %% [markdown]
# ## Ejercicio 14
#
# **Enunciado:** Crea una función que retorne las palabras de una lista que comiencen con una letra en específico. Usa la función filter().

# %%
def palabras_por_letra(palabras, letra):
    resultado = list(filter(lambda palabra: palabra.lower().startswith(letra.lower()), palabras))
    return resultado

lista = ["manzana", "pera", "melón", "plátano", "mandarina"]
print(palabras_por_letra(lista, "m"))
# Out:
# ['manzana', 'melón', 'mandarina']

# %% [markdown]
# ## Ejercicio 15
#
# **Enunciado:** Crea una función lambda que sume 3 a cada número de una lista dada.

# %%
sumar_tres = lambda lista: list(map(lambda numero: numero + 3, lista))

print(sumar_tres([1, 2, 3, 4, 5]))
# Out:
# [4, 5, 6, 7, 8]

# %% [markdown]
# ## Ejercicio 16
#
# **Enunciado:** Escribe una función que tome una cadena de texto y un número entero n como parámetros y devuelva una lista de todas las palabras que sean más largas que n. Usa la función filter().

# %%
def palabras_mas_largas(texto, n):
    palabras = texto.split()
    resultado = list(filter(lambda palabra: len(palabra) > n, palabras))
    return resultado

print(palabras_mas_largas("Estamos aprendiendo Python en clase", 5))
# Out:
# ['Estamos', 'aprendiendo', 'Python']

# %% [markdown]
# ## Ejercicio 17
#
# **Enunciado:** Crea una función que tome una lista de dígitos y devuelva el número correspondiente. Por ejemplo, [5,7,2] corresponde al número 572. Usa la función reduce().

# %%
from functools import reduce


def lista_a_numero(digitos):
    numero = reduce(lambda acumulado, digito: acumulado * 10 + digito, digitos)
    return numero

print(lista_a_numero([5, 7, 2]))
# Out:
# 572

# %% [markdown]
# ## Ejercicio 18
#
# **Enunciado:** Escribe un programa en Python que cree una lista de diccionarios con información de estudiantes (nombre, edad, calificación) y use filter para extraer a los estudiantes con una calificación mayor o igual a 90.

# %%
estudiantes = [
    {"nombre": "Ana", "edad": 20, "calificacion": 95},
    {"nombre": "Luis", "edad": 21, "calificacion": 82},
    {"nombre": "Marta", "edad": 19, "calificacion": 90},
    {"nombre": "Carlos", "edad": 22, "calificacion": 75}
]

estudiantes_destacados = list(filter(lambda estudiante: estudiante["calificacion"] >= 90, estudiantes))

print(estudiantes_destacados)
# Out:
# [{'nombre': 'Ana', 'edad': 20, 'calificacion': 95}, {'nombre': 'Marta', 'edad': 19, 'calificacion': 90}]

# %% [markdown]
# ## Ejercicio 19
#
# **Enunciado:** Crea una función lambda que filtre los números impares de una lista dada.

# %%
filtrar_impares = lambda lista: list(filter(lambda numero: numero % 2 != 0, lista))

print(filtrar_impares([1, 2, 3, 4, 5, 6, 7, 8, 9]))
# Out:
# [1, 3, 5, 7, 9]

# %% [markdown]
# ## Ejercicio 20
#
# **Enunciado:** Para una lista con elementos de tipo integer y string, obtén una nueva lista solo con los valores int. Usa la función filter().

# %%
datos = [1, "hola", 2, "python", 3, "clase"]

solo_enteros = list(filter(lambda elemento: type(elemento) == int, datos))

print(solo_enteros)
# Out:
# [1, 2, 3]

# %% [markdown]
# ## Ejercicio 21
#
# **Enunciado:** Crea una función que calcule el cubo de un número dado mediante una función lambda.

# %%
calcular_cubo = lambda numero: numero ** 3

print(calcular_cubo(4))
# Out:
# 64

# %% [markdown]
# ## Ejercicio 22
#
# **Enunciado:** Dada una lista numérica, obtén el producto total de los valores. Usa la función reduce().

# %%
from functools import reduce

numeros = [2, 3, 4, 5]
producto_total = reduce(lambda acumulado, numero: acumulado * numero, numeros)

print(producto_total)
# Out:
# 120

# %% [markdown]
# ## Ejercicio 23
#
# **Enunciado:** Concatena una lista de palabras. Usa la función reduce().

# %%
from functools import reduce

palabras = ["Estoy", "aprendiendo", "Python"]
frase = reduce(lambda acumulado, palabra: acumulado + " " + palabra, palabras)

print(frase)
# Out:
# Estoy aprendiendo Python

# %% [markdown]
# ## Ejercicio 24
#
# **Enunciado:** Calcula la diferencia total en los valores de una lista. Usa la función reduce().

# %%
from functools import reduce

valores = [100, 20, 10, 5]
diferencia_total = reduce(lambda acumulado, numero: acumulado - numero, valores)

print(diferencia_total)
# Out:
# 65

# %% [markdown]
# ## Ejercicio 25
#
# **Enunciado:** Crea una función que cuente el número de caracteres en una cadena de texto dada.

# %%
def contar_caracteres(texto):
    return len(texto)

print(contar_caracteres("Hola Python"))
# Out:
# 11

# %% [markdown]
# ## Ejercicio 26
#
# **Enunciado:** Crea una función lambda que calcule el resto de la división entre dos números dados.

# %%
calcular_resto = lambda numero1, numero2: numero1 % numero2

print(calcular_resto(10, 3))
# Out:
# 1

# %% [markdown]
# ## Ejercicio 27
#
# **Enunciado:** Crea una función que calcule el promedio de una lista de números.

# %%
def promedio(numeros):
    return sum(numeros) / len(numeros)

print(promedio([6, 7, 8, 9]))
# Out:
# 7.5

# %% [markdown]
# ## Ejercicio 28
#
# **Enunciado:** Crea una función que busque y devuelva el primer elemento duplicado en una lista dada.

# %%
def primer_duplicado(lista):
    elementos_vistos = set()

    for elemento in lista:
        if elemento in elementos_vistos:
            return elemento
        elementos_vistos.add(elemento)

    return None

print(primer_duplicado([1, 3, 4, 2, 3, 5, 4]))
# Out:
# 3

# %% [markdown]
# ## Ejercicio 29
#
# **Enunciado:** Crea una función que convierta una variable en una cadena de texto y enmascare todos los caracteres con el carácter '#' excepto los últimos cuatro.

# %%
def enmascarar(variable):
    texto = str(variable)

    if len(texto) <= 4:
        return texto

    parte_oculta = "#" * (len(texto) - 4)
    parte_visible = texto[-4:]

    return parte_oculta + parte_visible

print(enmascarar("123456789"))
# Out:
# #####6789

# %% [markdown]
# ## Ejercicio 30
#
# **Enunciado:** Crea una función que determine si dos palabras son anagramas, es decir, si están formadas por las mismas letras pero en diferente orden.

# %%
def son_anagramas(palabra1, palabra2):
    palabra1 = palabra1.lower().replace(" ", "")
    palabra2 = palabra2.lower().replace(" ", "")

    return sorted(palabra1) == sorted(palabra2)

print(son_anagramas("Roma", "Amor"))
# Out:
# True

# %% [markdown]
# ## Ejercicio 31
#
# **Enunciado:** Crea una función que solicite al usuario ingresar una lista de nombres y luego un nombre para buscar en esa lista. Si el nombre está en la lista, imprime un mensaje indicando que fue encontrado; de lo contrario, lanza una excepción.

# %%
class NombreNoEncontradoError(Exception):
    pass


def buscar_nombre(nombres, nombre_buscado):
    if nombre_buscado in nombres:
        return f"El nombre {nombre_buscado} fue encontrado."
    else:
        raise NombreNoEncontradoError(f"El nombre {nombre_buscado} no está en la lista.")


lista_nombres = ["Carlos", "Sergio", "Ana", "Marta"]

try:
    print(buscar_nombre(lista_nombres, "Carlos"))
    print(buscar_nombre(lista_nombres, "Luis"))
except NombreNoEncontradoError as error:
    print(f"Error: {error}")
# Out:
# El nombre Carlos fue encontrado.
# Error: El nombre Luis no está en la lista.

# %% [markdown]
# ## Ejercicio 32
#
# **Enunciado:** Crea una función que tome un nombre completo y una lista de empleados, busque el nombre en la lista y devuelva el puesto del empleado si se encuentra; de lo contrario, devuelve un mensaje indicando que la persona no trabaja aquí.

# %%
def buscar_puesto(nombre_completo, empleados):
    for empleado in empleados:
        if empleado["nombre"].lower() == nombre_completo.lower():
            return empleado["puesto"]

    return "La persona no trabaja aquí."

empleados = [
    {"nombre": "Ana García", "puesto": "Administrativa"},
    {"nombre": "Carlos López", "puesto": "Técnico de Sistemas"},
    {"nombre": "Marta Ruiz", "puesto": "Desarrolladora"}
]

print(buscar_puesto("Carlos López", empleados))
print(buscar_puesto("Sergio Valiente", empleados))
# Out:
# Técnico de Sistemas
# La persona no trabaja aquí.

# %% [markdown]
# ## Ejercicio 33
#
# **Enunciado:** Crea una función lambda que sume elementos correspondientes de dos listas dadas.

# %%
sumar_elementos = lambda lista1, lista2: list(map(lambda x, y: x + y, lista1, lista2))

print(sumar_elementos([1, 2, 3], [10, 20, 30]))
# Out:
# [11, 22, 33]

# %% [markdown]
# ## Ejercicio 34
#
# **Enunciado:** Crea la clase Arbol. Define un árbol genérico con un tronco y ramas como atributos. Métodos disponibles: crecer_tronco, nueva_rama, crecer_ramas, quitar_rama, info_arbol. Código a seguir: a. Inicializar un árbol con un tronco de longitud 1 y una lista vacía de ramas. b. Implementar el método crecer_tronco para aumentar la longitud del tronco en una unidad. c. Implementar el método nueva_rama para agregar una nueva rama de longitud 1 a la lista de ramas. d. Implementar el método crecer_ramas para aumentar en una unidad la longitud de todas las ramas existentes. e. Implementar el método quitar_rama para eliminar una rama en una posición específica. f. Implementar el método info_arbol para devolver información sobre la longitud del tronco, el número de ramas y sus longitudes. Caso de uso: a. Crear un árbol. b. Hacer crecer el tronco una unidad. c. Añadir una nueva rama. d. Hacer crecer todas las ramas una unidad. e. Añadir dos nuevas ramas. f. Retirar la rama situada en la posición 2. g. Obtener información sobre el árbol.

# %%
class Arbol:
    def __init__(self):
        self.tronco = 1
        self.ramas = []

    def crecer_tronco(self):
        self.tronco += 1

    def nueva_rama(self):
        self.ramas.append(1)

    def crecer_ramas(self):
        self.ramas = list(map(lambda rama: rama + 1, self.ramas))

    def quitar_rama(self, posicion):
        if 0 <= posicion < len(self.ramas):
            self.ramas.pop(posicion)
        else:
            print("No existe una rama en esa posición.")

    def info_arbol(self):
        return {
            "longitud_tronco": self.tronco,
            "numero_ramas": len(self.ramas),
            "longitudes_ramas": self.ramas
        }

arbol = Arbol()
arbol.crecer_tronco()
arbol.nueva_rama()
arbol.crecer_ramas()
arbol.nueva_rama()
arbol.nueva_rama()
arbol.quitar_rama(2)

print(arbol.info_arbol())
# Out:
# {'longitud_tronco': 2, 'numero_ramas': 2, 'longitudes_ramas': [2, 1]}

# %% [markdown]
# ## Ejercicio 35
#
# **Enunciado:** Crea la clase UsuarioBanco. Representa a un usuario de un banco con su nombre, saldo y si tiene o no cuenta corriente. Métodos: retirar_dinero, transferir_dinero, agregar_dinero. Código a seguir: a. Inicializar un usuario con nombre, saldo y un indicador (True o False) de cuenta corriente. b. Implementar retirar_dinero para sustraer dinero del saldo, lanzando un error si no es posible. c. Implementar transferir_dinero para transferir dinero desde otro usuario, lanzando un error en caso de fallo. d. Implementar agregar_dinero para aumentar el saldo del usuario. Caso de uso: a. Crear dos usuarios: Alicia con saldo inicial de 100 y Bob con saldo inicial de 50, ambos con cuenta corriente. b. Agregar 20 unidades al saldo de Bob. c. Transferir 80 unidades de Bob a Alicia. d. Retirar 50 unidades del saldo de Alicia.

# %%
class UsuarioBanco:
    def __init__(self, nombre, saldo, cuenta_corriente):
        self.nombre = nombre
        self.saldo = saldo
        self.cuenta_corriente = cuenta_corriente

    def retirar_dinero(self, cantidad):
        if cantidad <= 0:
            raise ValueError("La cantidad debe ser mayor que cero.")
        if cantidad > self.saldo:
            raise ValueError(f"{self.nombre} no tiene saldo suficiente.")

        self.saldo -= cantidad

    def agregar_dinero(self, cantidad):
        if cantidad <= 0:
            raise ValueError("La cantidad debe ser mayor que cero.")

        self.saldo += cantidad

    def transferir_dinero(self, usuario_origen, cantidad):
        if not self.cuenta_corriente or not usuario_origen.cuenta_corriente:
            raise ValueError("Ambos usuarios deben tener cuenta corriente.")

        usuario_origen.retirar_dinero(cantidad)
        self.agregar_dinero(cantidad)

alicia = UsuarioBanco("Alicia", 100, True)
bob = UsuarioBanco("Bob", 50, True)

try:
    bob.agregar_dinero(20)
    alicia.transferir_dinero(bob, 80)
except ValueError as error:
    print(f"Error en la transferencia: {error}")

try:
    alicia.retirar_dinero(50)
except ValueError as error:
    print(f"Error al retirar dinero: {error}")

print(f"Saldo final de Alicia: {alicia.saldo}")
print(f"Saldo final de Bob: {bob.saldo}")
# Out:
# Error en la transferencia: Bob no tiene saldo suficiente.
# Saldo final de Alicia: 50
# Saldo final de Bob: 70

# %% [markdown]
# ## Ejercicio 36
#
# **Enunciado:** Crea una función llamada procesar_texto. Procesa un texto según la opción especificada: contar_palabras, reemplazar_palabras o eliminar_palabra. Código a seguir: a. Crear una función contar_palabras que cuente el número de veces que aparece cada palabra en el texto y devuelva un diccionario. b. Crear una función reemplazar_palabras para sustituir una palabra_original por una palabra_nueva en el texto y devolver el texto modificado. c. Crear una función eliminar_palabra que elimine una palabra del texto y devuelva el texto sin ella. d. Crear la función procesar_texto que reciba un texto, una opción (contar, reemplazar, eliminar) y un número variable de argumentos según la opción elegida. Caso de uso: Verificar el funcionamiento completo de procesar_texto.

# %%
def contar_palabras(texto):
    palabras = texto.lower().split()
    contador = {}

    for palabra in palabras:
        contador[palabra] = contador.get(palabra, 0) + 1

    return contador


def reemplazar_palabras(texto, palabra_original, palabra_nueva):
    return texto.replace(palabra_original, palabra_nueva)


def eliminar_palabra(texto, palabra_eliminar):
    palabras = texto.split()
    palabras_filtradas = list(filter(lambda palabra: palabra != palabra_eliminar, palabras))
    return " ".join(palabras_filtradas)


def procesar_texto(texto, opcion, *args):
    if opcion == "contar":
        return contar_palabras(texto)
    elif opcion == "reemplazar":
        return reemplazar_palabras(texto, args[0], args[1])
    elif opcion == "eliminar":
        return eliminar_palabra(texto, args[0])
    else:
        return "Opción no válida."

texto = "python es divertido y python es útil"

print(procesar_texto(texto, "contar"))
print(procesar_texto(texto, "reemplazar", "python", "programar"))
print(procesar_texto(texto, "eliminar", "divertido"))
# Out:
# {'python': 2, 'es': 2, 'divertido': 1, 'y': 1, 'útil': 1}
# programar es divertido y programar es útil
# python es y python es útil

# %% [markdown]
# ## Ejercicio 37
#
# **Enunciado:** Genera un programa que nos indique si es de noche, de día o de tarde según la hora proporcionada por el usuario.

# %%
def indicar_momento_dia(hora):
    if 6 <= hora < 12:
        return "Es de día."
    elif 12 <= hora < 20:
        return "Es de tarde."
    elif 0 <= hora < 6 or 20 <= hora <= 23:
        return "Es de noche."
    else:
        return "Hora no válida."


print(indicar_momento_dia(10))
print(indicar_momento_dia(17))
print(indicar_momento_dia(22))
# Out:
# Es de día.
# Es de tarde.
# Es de noche.

# %% [markdown]
# ## Ejercicio 38
#
# **Enunciado:** Escribe un programa que determine qué calificación en texto tiene un alumno según su calificación numérica. Reglas: 0-69 insuficiente, 70-79 bien, 80-89 muy bien, 90-100 excelente.

# %%
def obtener_calificacion_texto(calificacion):
    if 0 <= calificacion <= 69:
        return "Insuficiente"
    elif 70 <= calificacion <= 79:
        return "Bien"
    elif 80 <= calificacion <= 89:
        return "Muy bien"
    elif 90 <= calificacion <= 100:
        return "Excelente"
    else:
        return "Calificación no válida"


print(obtener_calificacion_texto(65))
print(obtener_calificacion_texto(75))
print(obtener_calificacion_texto(85))
print(obtener_calificacion_texto(95))
# Out:
# Insuficiente
# Bien
# Muy bien
# Excelente

# %% [markdown]
# ## Ejercicio 39
#
# **Enunciado:** Escribe una función que tome dos parámetros: figura (una cadena que puede ser rectángulo, círculo o triángulo) y datos (una tupla con los datos necesarios para calcular el área de la figura).

# %%
import math


def calcular_area(figura, datos):
    figura = figura.lower()

    if figura == "rectangulo" or figura == "rectángulo":
        base, altura = datos
        return base * altura
    elif figura == "circulo" or figura == "círculo":
        radio = datos[0]
        return math.pi * radio ** 2
    elif figura == "triangulo" or figura == "triángulo":
        base, altura = datos
        return (base * altura) / 2
    else:
        return "Figura no válida."

print(calcular_area("rectangulo", (5, 4)))
print(calcular_area("circulo", (3,)))
print(calcular_area("triangulo", (6, 2)))
# Out:
# 20
# 28.274333882308138
# 6.0

# %% [markdown]
# ## Ejercicio 40
#
# **Enunciado:** Escribe un programa en Python que utilice condicionales para determinar el monto final de una compra en una tienda en línea, después de aplicar un descuento. El programa debe: a. Solicitar al usuario el precio original de un artículo. b. Preguntar si tiene un cupón de descuento (respuesta sí o no). c. Si la respuesta es sí, solicitar el valor del cupón de descuento. d. Aplicar el descuento al precio original, siempre que el valor del cupón sea válido (mayor a cero). e. Mostrar el precio final de la compra, considerando o no el descuento. f. Usar estructuras de control de flujo (if, elif, else) para llevar a cabo las acciones.

# %%
def calcular_precio_final(precio_original, tiene_cupon, descuento=0):
    if precio_original <= 0:
        return "El precio original debe ser válido y mayor que cero."

    if tiene_cupon:
        if descuento > 0:
            precio_final = precio_original - (precio_original * descuento / 100)
            return f"El precio final es: {precio_final:.2f} €"
        else:
            return "El cupón no es válido."
    else:
        return f"El precio final es: {precio_original:.2f} €"


print(calcular_precio_final(100, True, 20))
print(calcular_precio_final(100, False))
print(calcular_precio_final(100, True, 0))
# Out:
# El precio final es: 80.00 €
# El precio final es: 100.00 €
# El cupón no es válido.
